# %% [markdown]
# <a href="https://colab.research.google.com/github/Leshan21/Data-Structure-algorithm/blob/main/Deep_Learning_00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # test
